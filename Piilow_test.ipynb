# %% [markdown]
# # test1

# %%
from PIL import Image

# %%
rushMore = Image.open('rushmore .jpg')
'''
rushMore.show()
display(rushMore)
'''
rushMore
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x161 at 0x7F4D67930610>

# %%
rushMore.size
# Out:
# (300, 180)

# %%
newimg = Image.new("RGB",(300,180),(255,255,255))
newimg
# Out:
# <PIL.Image.Image image mode=RGB size=300x180 at 0x7F4D67930650>

# %% [markdown]
# # test2

# %%
rushMore.rotate(90)   #旋轉90度
# Out:
# <PIL.Image.Image image mode=RGB size=270x161 at 0x7F4D670850D0>

# %%
rushMore.rotate(45,expand = 1)    #expand預設0會顯示原圖大小，1則會顯示旋轉後的完整圖片
# Out:
# <PIL.Image.Image image mode=RGB size=306x305 at 0x7F4D67095D90>

# %% [markdown]
# # test3

# %%
from PIL import ImageColor

# %%
pictcrop = rushMore.crop((80,30,150,100))
pictcrop.size
# Out:
# (70, 70)

# %%
newimg = Image.new('RGB',(600,320),"Yellow")
for i in range(20,580,70):
  for j in range(20,300,70):
    newimg.paste(pictcrop,(i,j))
newimg
# Out:
# <PIL.Image.Image image mode=RGB size=600x320 at 0x7F4D67085290>

# %% [markdown]
# # test4

# %%
from PIL import ImageDraw

# %%
newImage = Image.new('RGBA', (300, 300), 'Yellow')
drawObj = ImageDraw.Draw(newImage)

drawObj.rectangle((0,0,299,299), outline = 'Black')
drawObj.ellipse((30,60,130,100), outline = 'Black')
drawObj.ellipse((65,65,95,95), fill = 'Blue')
drawObj.ellipse((170,60,270,100), outline = 'Black')
drawObj.ellipse((205,65,235,95), fill = 'Blue')
drawObj.polygon([(150,120), (180,180), (120,180), (150,120)], fill = 'Aqua')
drawObj.rectangle((100,210,200,240), fill = 'Red')
newImage
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F4D678D1710>

# %% [markdown]
# # test5

# %%
from PIL import ImageFilter

# %%
gblur = rushMore.filter(ImageFilter.GaussianBlur(2))
gblur
# Out:
# <PIL.Image.Image image mode=RGB size=270x161 at 0x7F4D5C959B90>
